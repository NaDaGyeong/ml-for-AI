# %% [markdown]
# <a href="https://colab.research.google.com/github/NaDaGyeong/ml-for-AI/blob/main/w7/w7_chap5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1-introducing_matplotlib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_05
# Out:
# /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_05

# %%
# We need to import matplotlib.pyplot for plotting
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Plotting lines

# %%
fb = pd.read_csv(
    'data/fb_stock_prices_2018.csv', index_col='date', parse_dates=True
)

# plt.plot(): to create a line plot
plt.plot(fb.index, fb.open)

# plt.show(): display it
plt.show()

# %%
# working in a Jupyter notebook
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd

fb = pd.read_csv(
    'data/fb_stock_prices_2018.csv', index_col='date', parse_dates=True
)
plt.plot(fb.index, fb.open)

# %% [markdown]
# ## Scatter plots

# %%
# Specify a format string for the plot as the third argument
# [marker][linestyle][color]:--k for a black dashed line
# We can omit the linestyle component
# We can make a scatter plot of red circles with the 'or' format string'
# o is for circles and r is for the color red
plt.plot('high', 'low', 'or', data=fb.head(20))

# %%
plt.plot(fb.index, fb.open,'o-r')

# %%
plt.plot(fb.index, fb.open,'-r')

# %% [markdown]
# | Marker | Linestyle | Color | Format String | Result |
# | :---: | :---: | :---: | :---: | --- |
# | | `-` | `b` | `-b` | blue solid line|
# | `.` |  | `k` | `.k` | black points|
# |  | `--` | `r` | `--r` | red dashed line|
# | `o` | `-` | `g` | `o-g` | green solid line with circles|
# | | `:` | `m` | `:m` | magenta dotted line|
# |`x` | `-.` | `c` | `x-.c` | cyan dot-dashed line with x's|

# %% [markdown]
# ## Histograms

# %%
quakes.query('magType=="ml"').mag
# Out:
# 0       1.35
# 1       1.29
# 2       3.42
# 3       0.44
# 6       1.70
#         ...
# 9325    0.51
# 9326    1.82
# 9328    1.00
# 9330    1.10
# 9331    0.66
# Name: mag, Length: 6803, dtype: float64

# %%
quakes = pd.read_csv('data/earthquakes.csv')
# Use the hist() function to create histograms
# The resulting histogram gives us an idea of the range of earthquake magnitudes 
# we can expect using the ml measurement technique
plt.hist(quakes.query('magType=="ml"').mag)
# Out:
# (array([6.400e+01, 4.450e+02, 1.137e+03, 1.853e+03, 2.114e+03, 8.070e+02,
#         2.800e+02, 9.200e+01, 9.000e+00, 2.000e+00]),
#  array([-1.26 , -0.624,  0.012,  0.648,  1.284,  1.92 ,  2.556,  3.192,
#          3.828,  4.464,  5.1  ]),
#  <a list of 10 Patch objects>)

# %%
# Bin size matters
# Change the number of bins the data is divided into and change what the histogram indicates the distribution to be
x = quakes.query('magType == "ml"').mag
fig, axes = plt.subplots(1, 2, figsize=(10, 3))
for ax, bins in zip(axes, [7, 35]):
    ax.hist(x, bins=bins)
    ax.set_title(f'bins param: {bins}')

# %% [markdown]
# ## Plot components

# %%
# plt.figure(): create Figure objects
# these will have zero Axes objects until a plot is added
fig = plt.figure()

# %% [markdown]
# ## Creating subplots

# %%
# plt.subplots(): creates a Figure object with Axes objects for subplots in the arrangement specified
fig, axes = plt.subplots(1, 2)

# %%
# add_axes: alternative to using plot.subplots()
fig = plt.figure(figsize=(3, 3))
outside = fig.add_axes([0.1, 0.1, 0.9, 0.9])
inside = fig.add_axes([0.7, 0.7, 0.25, 0.25])

# %% [markdown]
# ## Creating Plot Layouts with gridspec

# %%
# goal is to keep all the plots separate but not all equally sized
# add_gridspec()
fig = plt.figure(figsize=(8, 8))
gs = fig.add_gridspec(3, 3)
top_left = fig.add_subplot(gs[0, 0])
mid_left = fig.add_subplot(gs[1, 0])
top_right = fig.add_subplot(gs[:2, 1:])
bottom = fig.add_subplot(gs[2,:])

# %% [markdown]
# ## Saving plots

# %%
# savefig(): to save figure
fig.savefig('empty.png')

# %% [markdown]
# ## Cleaning up

# %%
# It is good practice to close them when we are donw with them so that we don't waste any resources
plt.close('all')

# %% [markdown]
# ## Additional plotting options

# %%
# Specifying figure size
# Control the size using figsize option
fig = plt.figure(figsize=(10, 4))

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# %%
# rcParams: acts like a dictionary, can easily overwrite what we wish for our session
# If we are resizing everything to the same size
import random
import matplotlib as mpl

rcparams_list = list(mpl.rcParams.keys())
random.seed(20) # make this repeatable
random.shuffle(rcparams_list)
sorted(rcparams_list[:20])
# Out:
# ['animation.avconv_args',
#  'axes.axisbelow',
#  'axes.formatter.limits',
#  'boxplot.capprops.color',
#  'boxplot.meanprops.marker',
#  'boxplot.whiskerprops.color',
#  'figure.dpi',
#  'image.interpolation',
#  'lines.dash_joinstyle',
#  'lines.markersize',
#  'lines.solid_capstyle',
#  'markers.fillstyle',
#  'mpl_toolkits.legacy_colorbar',
#  'savefig.transparent',
#  'scatter.edgecolors',
#  'text.latex.preview',
#  'xtick.color',
#  'xtick.labelbottom',
#  'xtick.top',
#  'ytick.major.right']

# %%
# Current default value for figsize
mpl.rcParams['figure.figsize']
# Out:
# [6.0, 4.0]

# %%
# Setting up new values
mpl.rcParams['figure.figsize'] = (300, 10)
mpl.rcParams['figure.figsize']
# Out:
# [300.0, 10.0]

# %%
# Restore the default settings by using the mpl.rcdefaults()
mpl.rcdefaults()
mpl.rcParams['figure.figsize']
# Out:
# [6.4, 4.8]

# %%
# reset default setting
plt.rc('figure', figsize=(20, 20)) # change `figsize` default to (20, 20)
plt.rcdefaults() # reset the default

# %% [markdown]
# # 2-plotting_with_pandas

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

fb = pd.read_csv(
    'data/fb_stock_prices_2018.csv', index_col='date', parse_dates=True
)
quakes = pd.read_csv('data/earthquakes.csv')
covid = pd.read_csv('data/covid19_cases.csv').assign(
    date=lambda x: pd.to_datetime(x.dateRep, format='%d/%m/%Y')
).set_index('date').replace(
    'United_States_of_America', 'USA'
).sort_index()['2020-01-18':'2020-09-18']

# %%
covid.head()
# Out:
#                dateRep  day  month  year  cases  deaths  \
# date
# 2020-01-18  18/01/2020   18      1  2020      0       0
# 2020-01-18  18/01/2020   18      1  2020      0       0
# 2020-01-18  18/01/2020   18      1  2020      0       0
# 2020-01-18  18/01/2020   18      1  2020      0       0
# 2020-01-18  18/01/2020   18      1  2020      0       0
#
#            countriesAndTerritories geoId countryterritoryCode  popData2019  \
# date
# 2020-01-18                 Croatia    HR                  HRV    4076246.0
# 2020-01-18                  Greece    EL                  GRC   10724599.0
# 2020-01-18          United_Kingdom    UK                  GBR   66647112.0
# 2020-01-18              Azerbaijan    AZ                  AZE   10047719.0
# 2020-01-18                 Bahrain    BH                  BHR    1641164.0
#
#            continentExp  \
# date
# 2020-01-18       Europe
# 2020-01-18       Europe
# 2020-01-18       Europe
# 2020-01-18       Europe
# 2020-01-18         Asia
# ...

# %% [markdown]
# ## Evolution over time

# %%
fb.head()
# Out:
#               open    high       low   close    volume
# date
# 2018-01-02  177.68  181.58  177.5500  181.42  18151903
# 2018-01-03  181.88  184.78  181.3300  184.67  16886563
# 2018-01-04  184.90  186.21  184.0996  184.33  13880896
# 2018-01-05  185.59  186.90  184.9300  186.85  13574535
# 2018-01-08  187.20  188.90  186.3300  188.28  17994726

# %%
# style
fb.plot(
    kind='line',
    y='open',
    figsize=(10, 5),
    style='-b',
    legend=False,
    title='Evolution of Facebook Open Price'
)

# %%
# we can pass each component separately with its associated keyword
# color, linestyle
fb.plot(
    kind='line',
    y='open',
    figsize=(10, 5),
    color='blue',
    linestyle='solid',
    legend=False,
    title='Evolution of Facebook Open Price'
)

# %%
# We can also pass in a list of columns to plot and style them individually
fb.first('1W').plot(
    y=['open', 'high', 'low', 'close'],
    style=['o-b', '--r', ':k', '.-g'],
    title='Facebook OHLC Prices during 1st Week of Trading 2018'
).autoscale()

# %%
# Creating subplots
fb.plot(
    kind='line',
    subplots=True,
    layout=(3, 2),
    figsize=(15, 10),
    title='Facebook Stock 2018'
)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe146bf7b50>,
# ...
#       dtype=object)

# %%
covid.pivot_table(
    index=covid.index, 
    columns='countriesAndTerritories', 
    values='cases'
).head()
# Out:
# countriesAndTerritories  Afghanistan  Albania  Algeria  Andorra  Angola  \
# date
# 2020-01-18                       0.0      NaN      0.0      NaN     NaN
# 2020-01-19                       0.0      NaN      0.0      NaN     NaN
# 2020-01-20                       0.0      NaN      0.0      NaN     NaN
# 2020-01-21                       0.0      NaN      0.0      NaN     NaN
# 2020-01-22                       0.0      NaN      0.0      NaN     NaN
#
# countriesAndTerritories  Anguilla  Antigua_and_Barbuda  Argentina  Armenia  \
# date
# 2020-01-18                    NaN                  NaN        NaN      0.0
# 2020-01-19                    NaN                  NaN        NaN      0.0
# 2020-01-20                    NaN                  NaN        NaN      0.0
# 2020-01-21                    NaN                  NaN        NaN      0.0
# 2020-01-22                    NaN                  NaN        NaN      0.0
#
# countriesAndTerritories  Aruba  ...  United_Republic_of_Tanzania  \
# ...

# %%
new_cases_rolling_average = covid.pivot_table(
    index=covid.index, 
    columns='countriesAndTerritories', 
    values='cases'
).rolling(7).mean()

new_cases_rolling_average.head()
# Out:
# countriesAndTerritories  Afghanistan  Albania  Algeria  Andorra  Angola  \
# date
# 2020-01-18                       NaN      NaN      NaN      NaN     NaN
# 2020-01-19                       NaN      NaN      NaN      NaN     NaN
# 2020-01-20                       NaN      NaN      NaN      NaN     NaN
# 2020-01-21                       NaN      NaN      NaN      NaN     NaN
# 2020-01-22                       NaN      NaN      NaN      NaN     NaN
#
# countriesAndTerritories  Anguilla  Antigua_and_Barbuda  Argentina  Armenia  \
# date
# 2020-01-18                    NaN                  NaN        NaN      NaN
# 2020-01-19                    NaN                  NaN        NaN      NaN
# 2020-01-20                    NaN                  NaN        NaN      NaN
# 2020-01-21                    NaN                  NaN        NaN      NaN
# 2020-01-22                    NaN                  NaN        NaN      NaN
#
# countriesAndTerritories  Aruba  ...  United_Republic_of_Tanzania  \
# ...

# %%
# Sometimes, we want to make subplots where each has a few variables in them for comparison
# plot countries that have had a similar number of cases in the same subplot
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

new_cases_rolling_average[['China']].plot(ax=axes[0], style='-.c')
new_cases_rolling_average[['Italy', 'Spain']].plot(
    ax=axes[1], style=['-', '--'], 
    title='7-day rolling average of new COVID-19 cases\n(source: ECDC)'
)
new_cases_rolling_average[['Brazil', 'India', 'USA']]\
    .plot(ax=axes[2], style=['--', ':', '-'])

# %%
fig, axes = plt.subplots(1,3,figsize=(15,5))

axes[0].plot(new_cases_rolling_average.index, new_cases_rolling_average.China)
axes[1].plot(new_cases_rolling_average.index, new_cases_rolling_average.Italy)
axes[1].plot(new_cases_rolling_average.index, new_cases_rolling_average.Spain)
axes[2].plot(new_cases_rolling_average.index, new_cases_rolling_average.Brazil)

# %%
# area plot: visualize the overall 7-day rolling average of new COVID-19 cases
# and how much each country is contributing to the total
cols = [
    col for col in new_cases_rolling_average.columns 
    if col not in ['USA', 'Brazil', 'India', 'Italy & Spain']
]
new_cases_rolling_average.assign(
    **{'Italy & Spain': lambda x: x.Italy + x.Spain}
).sort_index(axis=1).assign(
    Other=lambda x: x[cols].sum(axis=1)
).drop(columns=cols).plot(
    kind='area', figsize=(15, 5), 
    title='7-day rolling average of new COVID-19 cases\n(source: ECDC)'
)

# %%
# Better code
cols = [
    col for col in new_cases_rolling_average.columns 
    if col not in ['USA', 'Brazil', 'India', 'Italy_Spain']
]
cols2 = [
    col for col in new_cases_rolling_average.columns 
    if col not in ['USA', 'Brazil', 'India', 'Italy', 'Spain']
]
new_cases_rolling_average.assign(
    Italy_Spain = lambda x: x.Italy + x.Spain
).sort_index(axis=1).assign(
    Other=lambda x: x[cols2].sum(axis=1)
).drop(columns=cols).plot(
    kind='area', figsize=(15, 5), 
    title='7-day rolling average of new COVID-19 cases\n(source: ECDC)'
)

# %%
covid.groupby(
    ['countriesAndTerritories', pd.Grouper(freq='1D')]
).cases.sum()
# Out:
# countriesAndTerritories  date
# Afghanistan              2020-01-18     0
#                          2020-01-19     0
#                          2020-01-20     0
#                          2020-01-21     0
#                          2020-01-22     0
#                                        ..
# Zimbabwe                 2020-09-14    18
#                          2020-09-15     5
#                          2020-09-16    45
#                          2020-09-17    22
#                          2020-09-18    35
# Name: cases, Length: 42304, dtype: int64

# %%
covid.groupby(
    ['countriesAndTerritories', pd.Grouper(freq='1D')]
).cases.sum().unstack(0)
# Out:
# countriesAndTerritories  Afghanistan  Albania  Algeria  Andorra  Angola  \
# date
# 2020-01-18                       0.0      NaN      0.0      NaN     NaN
# 2020-01-19                       0.0      NaN      0.0      NaN     NaN
# 2020-01-20                       0.0      NaN      0.0      NaN     NaN
# 2020-01-21                       0.0      NaN      0.0      NaN     NaN
# 2020-01-22                       0.0      NaN      0.0      NaN     NaN
# ...                              ...      ...      ...      ...     ...
# 2020-09-14                      75.0    168.0    247.0      0.0    56.0
# 2020-09-15                      99.0    167.0    242.0     94.0    53.0
# 2020-09-16                      40.0    152.0    238.0      0.0    51.0
# 2020-09-17                      17.0    144.0    232.0      0.0   130.0
# 2020-09-18                       0.0    132.0    228.0     45.0   180.0
#
# countriesAndTerritories  Anguilla  Antigua_and_Barbuda  Argentina  Armenia  \
# date
# ...

# %%
covid.groupby(
    ['countriesAndTerritories', pd.Grouper(freq='1D')]
).cases.sum().unstack(0).apply('cumsum')
# Out:
# countriesAndTerritories  Afghanistan  Albania  Algeria  Andorra  Angola  \
# date
# 2020-01-18                       0.0      NaN      0.0      NaN     NaN
# 2020-01-19                       0.0      NaN      0.0      NaN     NaN
# 2020-01-20                       0.0      NaN      0.0      NaN     NaN
# 2020-01-21                       0.0      NaN      0.0      NaN     NaN
# 2020-01-22                       0.0      NaN      0.0      NaN     NaN
# ...                              ...      ...      ...      ...     ...
# 2020-09-14                   38716.0  11353.0  48254.0   1344.0  3335.0
# 2020-09-15                   38815.0  11520.0  48496.0   1438.0  3388.0
# 2020-09-16                   38855.0  11672.0  48734.0   1438.0  3439.0
# 2020-09-17                   38872.0  11816.0  48966.0   1438.0  3569.0
# 2020-09-18                   38872.0  11948.0  49194.0   1483.0  3749.0
#
# countriesAndTerritories  Anguilla  Antigua_and_Barbuda  Argentina  Armenia  \
# date
# ...

# %%
# Another way to visualize evolution over time is to look at the cumulative sum over time
fig, axes = plt.subplots(1, 3, figsize=(15, 3))

cumulative_covid_cases = covid.groupby(
    ['countriesAndTerritories', pd.Grouper(freq='1D')]
).cases.sum().unstack(0).apply('cumsum')

cumulative_covid_cases[['China']].plot(ax=axes[0], style='-.c')
cumulative_covid_cases[['Italy', 'Spain']].plot(
    ax=axes[1], style=['-', '--'], 
    title='Cumulative COVID-19 Cases\n(source: ECDC)'
)
cumulative_covid_cases[['Brazil', 'India', 'USA']]\
    .plot(ax=axes[2], style=['--', ':', '-'])

# %% [markdown]
# ## Visualizing relationships between

# %%
# Scatter plots
# Relationships between variables
fb.assign(
    max_abs_change=fb.high - fb.low
).plot(
    kind='scatter', x='volume', y='max_abs_change',
    title='Facebook Daily High - Low vs. Volume Traded'
)

# %%
# Let's try taking the logarithm(log) of the volume
# 1) Create a new column that is the log of the volume using np.log()
# 2) Use a logarithmic scale for the x-axis by passing in logx=True to the plot() method or calling plt.xscale('log')
fb.assign(
    max_abs_change=fb.high - fb.low
).plot(
    kind='scatter', x='volume', y='max_abs_change',
    title='Facebook Daily High - Low vs. log(Volume Traded)', 
    logx=True
)

# %%
# alpha
# To check the concentration of points(점들의 중복된 값을 보는 방법은 투명도를 높임)
fb.assign(
    max_abs_change=fb.high - fb.low
).plot(
    kind='scatter', x='volume', y='max_abs_change',
    title='Facebook Daily High - Low vs. log(Volume Traded)',
    logx=True, alpha=0.25
)

# %%
# Another plot type at our pisposal: hexbin
# Hexbins are another plot type that divide up the plot into hexagons, 
# which are shaded according to the density of points there
fb.assign(
    log_volume=np.log(fb.volume),
    max_abs_change=fb.high - fb.low
).plot(
    kind='hexbin',
    x='log_volume',
    y='max_abs_change',
    title='Facebook Daily High - Low vs. log(Volume Traded)',
    colormap='gray_r',
    gridsize=20, 
    sharex=False # we have to pass this to see the x-axis
)

# %%
# A correlation matrix depicts the magnitude and direction(positive or negative) of the correlation
fig, ax = plt.subplots(figsize=(20, 10))

# calculate the correlation matrix
fb_corr = fb.assign(
    log_volume=np.log(fb.volume),
    max_abs_change=fb.high - fb.low
).corr()

# create the heatmap and colorbar
im = ax.matshow(fb_corr, cmap='seismic')
im.set_clim(-1, 1)
fig.colorbar(im)

# label the ticks with the column names
labels = [col.lower() for col in fb_corr.columns]
ax.set_xticks(ax.get_xticks()[1:-1]) # to handle bug in matplotlib
ax.set_xticklabels(labels, rotation=45)
ax.set_yticks(ax.get_yticks()[1:-1]) # to handle bug in matplotlib
ax.set_yticklabels(labels)

# include the value of the correlation coefficient in the boxes
for (i, j), coef in np.ndenumerate(fb_corr):
    ax.text(
        i, j, fr'$\rho$ = {coef:.2f}', # raw (r), format (f) string
        ha='center', va='center', 
        color='white', fontsize=14
    )

# %%
fb_corr.loc['max_abs_change', ['volume', 'log_volume']]
# Out:
# volume        0.642027
# log_volume    0.731542
# Name: max_abs_change, dtype: float64

# %% [markdown]
# ## Visualizing distributions

# %%
# Histograms
fb.volume.plot(
    kind='hist', 
    title='Histogram of Daily Volume Traded in Facebook Stock'
)
plt.xlabel('Volume traded') # label the x-axis
# Out:
# Text(0.5, 0, 'Volume traded')

# %%
# multiple histograms on the sample plot to compare distributions by using the ax parameter to specify the same Axes object for each plot
# let's compare the usage and magnitude of the various measurement techniques (the magType column) in the data
fig, axes = plt.subplots(figsize=(8, 5))

for magtype in quakes.magType.unique():
    data = quakes.query(f'magType == "{magtype}"').mag
    if not data.empty:
        data.plot(
            kind='hist', ax=axes, alpha=0.4, 
            label=magtype, legend=True,
            title='Comparing histograms of earthquake magnitude by magType'
        )

plt.xlabel('magnitude') # label the x-axis
# Out:
# Text(0.5, 0, 'magnitude')

# %%
# Kernel Density Estimation (KDE)
# When working with continuous data, we can use KDEs
fb.high.plot(
    kind='kde', 
    title='KDE of Daily High Price for Facebook Stock'
)
plt.xlabel('Price ($)') # label the x-axis
# Out:
# Text(0.5, 0, 'Price ($)')

# %%
ax = fb.high.plot(kind='hist', density=True, alpha=0.5)
fb.high.plot(
    ax=ax, kind='kde', color='blue', 
    title='Distribution of Facebook Stock\'s Daily High Price in 2018'
)
plt.xlabel('Price ($)') # label the x-axis
# Out:
# Text(0.5, 0, 'Price ($)')

# %%
ax = fb.high.plot(kind='hist', density=True, alpha=0.5)
ax = fb.high.plot(
    ax=ax, kind='kde', color='blue', 
    title='Distribution of Facebook Stock\'s Daily High Price in 2018'
)
plt.xlabel('Price ($)')
# Out:
# Text(0.5, 0, 'Price ($)')

# %%
# We can estimate the CDF giving us the empirical cumulative distribution function(ECDF)
from statsmodels.distributions.empirical_distribution import ECDF

ecdf = ECDF(quakes.query('magType == "ml"').mag)
plt.plot(ecdf.x, ecdf.y)

# axis labels (we will cover this in chapter 6)
plt.xlabel('mag') # add x-axis label 
plt.ylabel('cumulative probability') # add y-axis label

# add title (we will cover this in chapter 6)
plt.title('ECDF of earthquake magnitude with magType ml')
# Out:
# Text(0.5, 1.0, 'ECDF of earthquake magnitude with magType ml')

# %%
# box plots: visualize potential outliers and the distribution using quartiles
fb.iloc[:,:4].plot(kind='box', title='Facebook OHLC Prices Box Plot')
plt.ylabel('price ($)') # label the x-axis
# Out:
# Text(0, 0.5, 'price ($)')

# %%
fb.iloc[:,:4].plot(kind='box', title='Facebook OHLC Prices Box Plot', notch=True)
plt.ylabel('price ($)') # label the x-axis
# Out:
# Text(0, 0.5, 'price ($)')

# %%
# Call the boxplot() method after calling groupby()
fb.assign(
    volume_bin=pd.cut(fb.volume, 3, labels=['low', 'med', 'high'])
).groupby('volume_bin').boxplot(
    column=['open', 'high', 'low', 'close'],
    layout=(1, 3), figsize=(12, 3)
)
plt.suptitle('Facebook OHLC Box Plots by Volume Traded', y=1.1)
# Out:
# Text(0.5, 1.1, 'Facebook OHLC Box Plots by Volume Traded')

# %%
# see the distribution of magnitudes across the different measurement methods for earthquakes
quakes[['mag', 'magType']].groupby('magType').boxplot(
    figsize=(15, 8), subplots=False
)
plt.title('Earthquake Magnitude Box Plots by magType')
plt.ylabel('magnitude') # label the y-axis
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# Text(0, 0.5, 'magnitude')

# %% [markdown]
# ## Counts and frequencies

# %%
quakes.parsed_place.value_counts()
# Out:
# Alaska                     3665
# California                 2861
# Nevada                      681
# Hawaii                      367
# Puerto Rico                 216
#                            ...
# Queen Charlotte Islands       1
# Uzbekistan                    1
# Prince Edward Islands         1
# Martinique                    1
# New Mexico                    1
# Name: parsed_place, Length: 110, dtype: int64

# %%
# The bars can be vertical(kind='bar') or horizontal(kind='barh')
# look at the top 15 places for earthquakes in our data
quakes.parsed_place.value_counts().iloc[14::-1,].plot(
    kind='barh', figsize=(10, 5),
    title='Top 15 Places for Earthquakes '
          '(September 18, 2018 - October 13, 2018)'
)
plt.xlabel('earthquakes') # label the x-axis
# Out:
# Text(0.5, 0, 'earthquakes')

# %%
# Let's see what the top places for tsunamis are
quakes.groupby('parsed_place').tsunami.sum().sort_values().iloc[-10:,].plot(
    kind='barh', figsize=(10, 5), 
    title='Top 10 Places for Tsunamis '
          '(September 18, 2018 - October 13, 2018)'
)
plt.xlabel('tsunamis') # label the x-axis
# Out:
# Text(0.5, 0, 'tsunamis')

# %%
# want to look how many earthquakes and tsunamis Indonesia gets on a daily basis
quakes.query('parsed_place == "Indonesia"').assign(
    time=lambda x: pd.to_datetime(x.time, unit='ms'),
    earthquake=1
)
# Out:
#       mag magType                    time  \
# 9     4.7      mb 2018-10-13 23:20:14.760
# 13    4.5      mb 2018-10-13 22:48:18.340
# 180   5.2     mww 2018-10-13 04:34:15.580
# 421   4.7      mb 2018-10-12 07:58:18.920
# 660   4.4      mb 2018-10-11 11:53:53.830
# ...   ...     ...                     ...
# 9041  4.3      mb 2018-09-18 18:45:05.750
# 9075  4.4      mb 2018-09-18 16:38:43.310
# 9108  4.0      mb 2018-09-18 14:16:21.100
# 9209  4.7      mb 2018-09-18 07:33:41.950
# 9212  4.7      mb 2018-09-18 07:27:16.260
#
#                                     place  tsunami parsed_place  earthquake
# 9         219km SSE of Saparua, Indonesia        0    Indonesia           1
# 13     120km SSW of Banda Aceh, Indonesia        0    Indonesia           1
# 180           25km E of Bitung, Indonesia        0    Indonesia           1
# 421   38km SSW of Nggongi Satu, Indonesia        0    Indonesia           1
# ...

# %%
quakes.query('parsed_place == "Indonesia"').assign(
    time=lambda x: pd.to_datetime(x.time, unit='ms'),
    earthquake=1
).set_index('time').resample('1D').sum().head()
# Out:
#              mag  tsunami  earthquake
# time
# 2018-09-18  22.1        0           5
# 2018-09-19  13.1        0           3
# 2018-09-20  12.8        0           3
# 2018-09-21   8.9        0           2
# 2018-09-22  23.1        0           5

# %%
quakes.query('parsed_place == "Indonesia"').assign(
    time=lambda x: pd.to_datetime(x.time, unit='ms'),
    earthquake=1
).set_index('time').groupby(pd.Grouper(freq='1D')).sum().head()
# Out:
#              mag  tsunami  earthquake
# time
# 2018-09-18  22.1        0           5
# 2018-09-19  13.1        0           3
# 2018-09-20  12.8        0           3
# 2018-09-21   8.9        0           2
# 2018-09-22  23.1        0           5

# %%
# Look further into the number of tsunamis&earthquakes in Indonesia each day
indonesia_quakes = quakes.query('parsed_place == "Indonesia"').assign(
    time=lambda x: pd.to_datetime(x.time, unit='ms'),
    earthquake=1
).set_index('time').resample('1D').sum()

# format the datetimes in the index for the x-axis
indonesia_quakes.index = indonesia_quakes.index.strftime('%b\n%d')

indonesia_quakes.plot(
    y=['earthquake', 'tsunami'], kind='bar', figsize=(15, 3), 
    rot=0, label=['earthquakes', 'tsunamis'], 
    title='Earthquakes and Tsunamis in Indonesia '
          '(September 18, 2018 - October 13, 2018)'
)

# label the axes (discussed in chapter 6)
plt.xlabel('date')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
quakes.groupby(['parsed_place', 'tsunami']).mag.count()
# Out:
# parsed_place                    tsunami
# Afghanistan                     0             6
# Alaska                          0          3660
#                                 1             5
# Argentina                       0            11
# Arizona                         0             2
#                                            ...
# Washington                      0           157
# Western Indian-Antarctic Ridge  0             1
# Western Xizang                  0             1
# Wyoming                         0            42
# Yemen                           0             1
# Name: mag, Length: 119, dtype: int64

# %%
quakes.groupby(['parsed_place', 'tsunami']).mag.count()\
    .unstack()
# Out:
# tsunami                              0    1
# parsed_place
# Afghanistan                        6.0  NaN
# Alaska                          3660.0  5.0
# Argentina                         11.0  NaN
# Arizona                            2.0  NaN
# Arkansas                           3.0  NaN
# ...                                ...  ...
# Washington                       157.0  NaN
# Western Indian-Antarctic Ridge     1.0  NaN
# Western Xizang                     1.0  NaN
# Wyoming                           42.0  NaN
# Yemen                              1.0  NaN
#
# [110 rows x 2 columns]

# %%
quakes.groupby(['parsed_place', 'tsunami']).mag.count()\
    .unstack().apply(lambda x: x / x.sum(), axis=1)
# Out:
# tsunami                                0         1
# parsed_place
# Afghanistan                     1.000000       NaN
# Alaska                          0.998636  0.001364
# Argentina                       1.000000       NaN
# Arizona                         1.000000       NaN
# Arkansas                        1.000000       NaN
# ...                                  ...       ...
# Washington                      1.000000       NaN
# Western Indian-Antarctic Ridge  1.000000       NaN
# Western Xizang                  1.000000       NaN
# Wyoming                         1.000000       NaN
# Yemen                           1.000000       NaN
#
# [110 rows x 2 columns]

# %%
# Create grouped bars from a single column's values by using groupby() and unstack()
quakes.groupby(['parsed_place', 'tsunami']).mag.count()\
    .unstack().apply(lambda x: x / x.sum(), axis=1)\
    .rename(columns={0: 'no', 1: 'yes'})\
    .sort_values('yes', ascending=False)[7::-1]\
    .plot.barh(
        title='Frequency of a tsunami accompanying an earthquake'
    )

# move legend to the right of the plot
plt.legend(title='tsunami?', bbox_to_anchor=(1, 0.65))

# label the axes (discussed in chapter 6)
plt.xlabel('percentage of earthquakes')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
quakes.groupby(['parsed_place', 'tsunami']).mag.count()\
    .unstack().apply(lambda x: x / x.sum(), axis=1)\
    .rename(columns={0: 'no', 1: 'yes'})\
    .sort_values('yes', ascending=False)[7::-1]\
    .plot(kind='barh',
        title='Frequency of a tsunami accompanying an earthquake'
    )

# move legend to the right of the plot
plt.legend(title='tsunami?', bbox_to_anchor=(1, 0.65))

# label the axes (discussed in chapter 6)
plt.xlabel('percentage of earthquakes')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
# Which methods of measuring earthquake magnitude are most prevalent?
quakes.magType.value_counts().plot(
    kind='bar', title='Earthquakes Recorded per magType', rot=0
)

# label the axes (discussed in chapter 6)
plt.xlabel('magType')
plt.ylabel('earthquakes')
# Out:
# Text(0, 0.5, 'earthquakes')

# %%
# Want to see how many earthquakes of a given magnitude there were and to distinguish them by magType
# 1) Which magnitudes occur most often across magType -> ml
# 2) The relative ranges of magnitude that each magType yields
# 3) The most common values for magType

pivot = quakes.assign(
    mag_bin=lambda x: np.floor(x.mag)
).pivot_table(
    index='mag_bin', columns='magType', values='mag', aggfunc='count'
)
pivot.plot.bar(
    stacked=True, rot=0, ylabel='earthquakes', 
    title='Earthquakes by integer magnitude and magType'
)

# %%
# Normalized stacked bar plot
normalized_pivot = pivot.fillna(0).apply(lambda x: x / x.sum(), axis=1)
ax = normalized_pivot.plot.bar(
    stacked=True, rot=0, figsize=(10, 5),
    title='Percentage of earthquakes by integer magnitude for each magType'
)
ax.legend(bbox_to_anchor=(1, 0.8)) # move legend to the right of the plot
plt.ylabel('percentage') # label the axes
# Out:
# Text(0, 0.5, 'percentage')

# %%
quakes.groupby(['parsed_place', 'tsunami']).mag.count()\
    .unstack().apply(lambda x: x / x.sum(), axis=1)\
    .rename(columns={0: 'no', 1: 'yes'})\
    .sort_values('yes', ascending=False)[7::-1]\
    .plot.barh(
        title='Frequency of a tsunami accompanying an earthquake', 
        stacked=True
    )

# move legend to the right of the plot
plt.legend(title='tsunami?', bbox_to_anchor=(1, 0.65))

# label the axes (discussed in chapter 6)
plt.xlabel('percentage of earthquakes')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# # 3-pandas_plotting_module

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

fb = pd.read_csv(
    'data/fb_stock_prices_2018.csv', index_col='date', parse_dates=True
)

# %% [markdown]
# ## Scatter matrix

# %%
# scatter_matrix() function
from pandas.plotting import scatter_matrix
scatter_matrix(fb, figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe130defa90>,
# ...
#       dtype=object)

# %%
# ask for the KDE by passing in diagonal='kde'
scatter_matrix(fb, figsize=(10, 10), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe1307fda10>,
# ...
#       dtype=object)

# %% [markdown]
# ## Lag plot

# %%
# lag plot: to check for relationships among values at a given time to those a certain number of periods before that time
from pandas.plotting import lag_plot
np.random.seed(0) # make this repeatable
lag_plot(pd.Series(np.random.random(size=200)))

# %%
# With our stock data, we know that the prices on a given day are determined by what happened the day before
# Stock prices are highly autocorrelated
lag_plot(fb.close)

# %%
lag_plot(fb.close, lag=5)

# %% [markdown]
# ## Autocorrelation plots

# %%
# Autocorrelation plots: show us how many periods of autocorrelation our data contains
# Random data will not have any significant autocorrelation
from pandas.plotting import autocorrelation_plot
np.random.seed(0) # make this repeatable
autocorrelation_plot(pd.Series(np.random.random(size=200)))

# %%
# Stock data, on the other hand, does have significant autocorrelation
autocorrelation_plot(fb.close)

# %% [markdown]
# ## Bootstrap plot

# %%
# Bootstrap: helps us understand the uncertainty in our summary statistics
from pandas.plotting import bootstrap_plot
fig = bootstrap_plot(fb.volume, fig=plt.figure(figsize=(10, 6)))

# %% [markdown]
# # Task 1

# %%
fb.head()
# Out:
#               open    high       low   close    volume
# date
# 2018-01-02  177.68  181.58  177.5500  181.42  18151903
# 2018-01-03  181.88  184.78  181.3300  184.67  16886563
# 2018-01-04  184.90  186.21  184.0996  184.33  13880896
# 2018-01-05  185.59  186.90  184.9300  186.85  13574535
# 2018-01-08  187.20  188.90  186.3300  188.28  17994726

# %%
fig, axes = plt.subplots(1, 2)
axes[0].plot(fb.index, fb.open, '.-r')
axes[1].plot(fb.index, fb.high, '.--b')

# %%
fig = plt.figure(figsize=(3, 3))
outside = fig.add_axes([0.1, 0.1, 0.9, 0.9])
inside = fig.add_axes([0.7, 0.7, 0.25, 0.25])

outside.plot(fb.index, fb.open, '.-r')
inside.plot(fb.index, fb.high, '.--b')

# %% [markdown]
# # Task 2

# %%
new_cases_rolling_average.columns
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua_and_Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        ...
#        'United_Republic_of_Tanzania', 'United_States_Virgin_Islands',
#        'Uruguay', 'Uzbekistan', 'Venezuela', 'Vietnam', 'Western_Sahara',
#        'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='countriesAndTerritories', length=210)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

new_cases_rolling_average[['USA']].plot(ax=axes[0], style='-.c')
new_cases_rolling_average[['Afghanistan', 'United_Republic_of_Tanzania']].plot(
    ax=axes[1], style=['-', '--'], 
    title='7-day rolling average of new COVID-19 cases\n(source: ECDC)'
)
new_cases_rolling_average[['Vietnam', 'India']]\
    .plot(ax=axes[2], style=['--', ':', '-'])

# %%
cols = [
    col for col in new_cases_rolling_average.columns 
    if col not in ['USA', 'Afghanistan', 'United_Republic_of_Tanzania', 'Vietnam_India']
]
cols2 = [
    col for col in new_cases_rolling_average.columns 
    if col not in ['USA', 'Afghanistan', 'United_Republic_of_Tanzania','Vietnam','India']
]
new_cases_rolling_average.assign(
    Vietnam_India = lambda x: x.Vietnam + x.India
).sort_index(axis=1).assign(
    Other=lambda x: x[cols2].sum(axis=1)
).drop(columns=cols).plot(
    kind='area', figsize=(15, 5), 
    title='7-day rolling average of new COVID-19 cases\n(source: ECDC)'
)

# %% [markdown]
# # Task 3

# %%
# Look further into the number of tsunamis&earthquakes in Indonesia each day
indonesia_quakes = quakes.query('parsed_place == "Indonesia"').assign(
    time=lambda x: pd.to_datetime(x.time, unit='ms'),
    earthquake=1
).set_index('time').resample('1D').sum()

# format the datetimes in the index for the x-axis
indonesia_quakes.index = indonesia_quakes.index.strftime('%b\n%d')

indonesia_quakes.plot(
    y=['earthquake', 'tsunami'], kind='bar', figsize=(15, 3), 
    rot=0, label=['earthquakes', 'tsunamis'], 
    title='Earthquakes and Tsunamis in Indonesia '
          '(September 18, 2018 - October 13, 2018)'
)

# label the axes (discussed in chapter 6)
plt.xlabel('date')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
# Look further into the number of tsunamis&earthquakes in Indonesia each day
indonesia_quakes = quakes.query('parsed_place == "Indonesia"').assign(
    time=lambda x: pd.to_datetime(x.time, unit='ms'),
    earthquake=1
).set_index('time').resample('1D').sum()

# format the datetimes in the index for the x-axis
indonesia_quakes.index = indonesia_quakes.index.strftime('%b\n%d')

indonesia_quakes.plot(
    stacked=True,
    y=['earthquake', 'tsunami'], kind='bar', figsize=(15, 3), 
    rot=0, label=['earthquakes', 'tsunamis'], 
    title='Earthquakes and Tsunamis in Indonesia '
          '(September 18, 2018 - October 13, 2018)'
)

# label the axes (discussed in chapter 6)
plt.xlabel('date')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
# Normalized stacked bar plot
# indonesia_quakes의 earthquake와 tsunami 변수만을 가지고 normalized를 해야 함
normalized_pivot =indonesia_quakes.apply(lambda x: x / x.sum(), axis=1)
ax = normalized_pivot.plot.bar(
    y=['earthquake', 'tsunami'],
    stacked=True, rot=0, figsize=(15, 3),
    title='Earthquakes and Tsunamis in Indonesia '
          '(September 18, 2018 - October 13, 2018)'
)
ax.legend(bbox_to_anchor=(1, 0.8)) # move legend to the right of the plot
plt.ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
indonesia_quakes[['tsunami','earthquake']].apply(lambda x: x / x.sum(), axis=1).plot(
    y=['earthquake', 'tsunami'], kind='bar', figsize=(15,3),
    rot=0, label=['earthquake', 'tsunami'],
    title='Earthquakes and Tsunamis in Indonesia '
          '(September 18, 2018 - October 13, 2018)',
          stacked=True
)
